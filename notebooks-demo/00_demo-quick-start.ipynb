# %% [markdown]
# # biocharStability - a tiny demonstration
#
# This notebook shows the basics of how to use the functions contained in the ``biocharStability`` library.
#
# __Pre-requisites:__
# - your forked/cloned/downloaded the GitHub repository (https://github.com/SLU-biochar/biocharStability)
# - you created a python environment (``conda create -n biocharstab python=3.9``)
# - in this environment, you installed via pip (in editable format) the ``biocharStability`` library (``pip install -e .``).
#
# Note: core dependencies will also be installed via the pip command. If something is missing in the environment, install it via conda or pip, on your own, whenever an error occurs, telling a package is missing  :-)
#
# More info on installation here https://github.com/SLU-biochar/biocharStability#how-to-install-or-use
#
# __Documentation:__
#
# The library has an automatically generated documentation. Go to the folder ``docs`` and open the ``index.html`` file in a web browser.
#
# __Contents of this notebook:__
# - importing the library
# - access functions documentation strings
# - load the data
# - do something with the data

# %% [markdown]
# ## The basics: load the data

# %%
# importing the library (and other libraries as needed)
import biocharStability as bs
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# functions available can be accessed by typing bs. 
# press tab key after ``bs.``, to get a dropdown of available functions / submodules
# put a ``?`` at the end of function and run the cell to load the docstrings
bs.utils.load_articles?

# %%
# load the data, in pandas dataframes
fp = '../biocharStability/database/biochar_incubation_database_2022-03-22_live.xlsx' # relative or absolute path to database .xlsx file
metadata, schema, metadata_column_sets = bs.load_metadata(filepath=fp)
data = bs.load_data(filepath=fp)
articles = bs.load_articles(filepath=fp)
validation = bs.load_validation(filepath=fp)
# Out:
# Metadata loaded, with 181 rows
# Data loaded, with 2814 rows
# Articles loaded, with 75 rows
# Validation loaded, with 128 rows

# %%
# calculate some statistics
bs.print_database_completion_stats(articles, data, metadata, validation, schema)
# Out:
# ** Completion statistics **
# 	** table: articles **
# Number of data cells : 1080 ( 100.0 % )
# Number of cells with 'available' information : 743 ( 68.8 % )
# Number of cells with 'not available' information : 0 ( 0.0 % )
# Number of empty cells (NaN) : 337 ( 31.2 % )
# 	** table: data **
# Number of data cells : 73060 ( 100.0 % )
# Number of cells with 'available' information : 24127 ( 33.0 % )
# Number of cells with 'not available' information : 0 ( 0.0 % )
# Number of empty cells (NaN) : 48933 ( 67.0 % )
# 	** table: metadata **
# Number of data cells : 11200 ( 100.0 % )
# Number of cells with 'available' information : 6884 ( 61.5 % )
# Number of cells with 'not available' information : 2185 ( 19.5 % )
# Number of empty cells (NaN) : 2131 ( 19.0 % )
# 	** table: validation **
# Number of data cells : 13589 ( 100.0 % )
# Number of cells with 'available' information : 2976 ( 21.9 % )
# Number of cells with 'not available' information : 2488 ( 18.3 % )
# Number of empty cells (NaN) : 8125 ( 59.8 % )
#
# ** Number of articles & observations from which `data` was extracted **
# 	articles: 17
# 	observations: 130
#
# ** Number of articles & observations from which `metadata` was extracted **
# 	articles: 23
# 	observations: 175
#
# ** Number of articles & observations for which `validation` data was recorded **
# 	observations: 127

# %%
# some more stats
bs.print_metadata_stats(metadata)
# Out:
# Biomass types included:
# |           |   Counts |    % |
# |-----------|----------|------|
# | wood      |       80 | 45.7 |
# | nan       |       38 | 21.7 |
# | crop      |       32 | 18.3 |
# | grass     |       18 | 10.3 |
# | manure    |        4 |  2.3 |
# | leaf      |        2 |  1.1 |
# | biosolids |        1 |  0.6 |
#
#
# Pyrolysis types included:
# |           |   Counts |    % |
# |-----------|----------|------|
# | pyr-slow  |      125 | 71.4 |
# | nan       |       38 | 21.7 |
# | no-treat  |        5 |  2.9 |
# | gas       |        4 |  2.3 |
# | htc       |        2 |  1.1 |
# | pyr-flash |        1 |  0.6 |

# %%
# look at the dataframes
metadata.head(3)
# Out:
#         ID_art AuthorDate               NameObs Replicates  \
# ID_obs
# 1            1  Major2010  Black C material 1-2          3
# 3            9     Wu2016                    LN          3
# 4            9     Wu2016                    SD          3
#
#                             Biomass BiomassClass  BiomassLignin  \
# ID_obs
# 1       Prunings of old mango trees         wood         0.2375
# 3           rice straw, 13C labeled         crop            NaN
# 4           rice straw, 13C labeled         crop            NaN
#
#                                                 Pyrolysis PyrolysisClass  \
# ID_obs
# 1       Biochar 1: mound of tightly packed logs (appro...       pyr-slow
# 3                GDL-1500X tubular furnace, N2 atmosphere       pyr-slow
# 4                GDL-1500X tubular furnace, N2 atmosphere       pyr-slow
#
#           HHT  ...  ParticleSize BulkDensity TrueDensity OxidationH2O2  \
# ID_obs         ...
# 1       500.0  ...  <0.9mm sieve          na          na            na
# 3       500.0  ...            na          na          na            na
# 4       500.0  ...            na          na          na            na
#
#        BiocharYield   δ ¹³C biochar      δ ¹³C soil ID_Lehmann2019  \
# ID_obs
# 1                na  -28.2 to -28.9  -10,9 to -13,5            I29
# 3                na          570.68          -24.51            I24
# 4                na          570.68          -23.87            I25
#
#        ID_Woolf2021 ID_Lehmann2021
# ID_obs
# 1               W49            L48
# 3               W64            L63
# 4               W65            L64
#
# [3 rows x 64 columns]

# %%
data.head(10)
# Out:
#    ID_obs ID_art time                 date F_tot_abs d_bc d_soc  F_bc_abs  \
# 4       1      1    0  2009-05-17 00:00:00       NaN  NaN   NaN       NaN
# 5       1      1    1  2009-05-18 00:00:00       NaN  NaN   NaN  0.013208
# 6       1      1   15  2009-06-01 00:00:00       NaN  NaN   NaN  0.021919
# 7       1      1   38  2009-06-24 00:00:00       NaN  NaN   NaN         0
# 8       1      1   70  2009-07-26 00:00:00       NaN  NaN   NaN  0.009886
# 9       1      1  127  2009-09-21 00:00:00       NaN  NaN   NaN  0.190717
# 10      1      1  185  2009-11-18 00:00:00       NaN  NaN   NaN  0.030045
# 11      1      1  202  2009-12-05 00:00:00       NaN  NaN   NaN   0.00113
# 12      1      1  217  2009-12-20 00:00:00       NaN  NaN   NaN  0.000008
# 13      1      1  232  2010-01-04 00:00:00       NaN  NaN   NaN  0.000008
#
#    F_soc_abs  F_bc_rel  ... k_bc_rel0 k_bc_reld C_bc_loss_abs C_bc_loss_rel  \
# 4        NaN         0  ...         0         0             0             0
# 5        NaN  0.000008  ...  0.000842  0.000842      0.013208      0.000842
# 6        NaN  0.000014  ...    0.0001    0.0001      0.035127       0.00224
# 7        NaN         0  ...         0         0      0.035127       0.00224
# 8        NaN  0.000006  ...   0.00002   0.00002      0.045013       0.00287
# 9        NaN  0.000122  ...  0.000213  0.000214       0.23573      0.015031
# 10       NaN  0.000019  ...  0.000033  0.000034      0.265775      0.016946
# 11       NaN  0.000001  ...  0.000004  0.000004      0.266905      0.017019
# 12       NaN       0.0  ...       0.0       0.0      0.266913      0.017019
# 13       NaN       0.0  ...       0.0       0.0      0.266921       0.01702
#
#    C_bc_rem_abs C_bc_rem_rel C_tot_loss_abs C_tot_loss_rel P_soc_abs P_soc_rel
# 4       1568.32            1            NaN            NaN       NaN       NaN
# 5     15.669992     0.999158            NaN            NaN       NaN       NaN
# 6     15.648073      0.99776            NaN            NaN       NaN       NaN
# 7     15.648073      0.99776            NaN            NaN       NaN       NaN
# 8     15.638187      0.99713            NaN            NaN       NaN       NaN
# 9      15.44747     0.984969            NaN            NaN       NaN       NaN
# 10    15.417425     0.983054            NaN            NaN       NaN       NaN
# 11    15.416295     0.982981            NaN            NaN       NaN       NaN
# 12    15.416287     0.982981            NaN            NaN       NaN       NaN
# 13    15.416279      0.98298            NaN            NaN       NaN       NaN
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Plot some time series

# %% [markdown]
# The three main columns:
# - C_bc_rem_rel > biochar C remaining in % (0-1)
# - C_bc_loss_rel > biochar C lost in % (0-1)
# - k_bc_rel0 > decay rates in gC per gC intial per day

# %%
# select the decay data from a specific observations, and plot one curve from it
obs66 = bs.select_mineralization_data(ID_obs=40, data=data)
f, ax = plt.subplots()
ax.scatter(obs66['time'], obs66['C_bc_rem_rel']*100)
ax.set_xlabel('Time, days')
ax.set_ylabel('Biochar C remaining, %')
# Out:
# Text(0, 0.5, 'Biochar C remaining, %')

# %%
months_cutoffs, sets_incubations, sets_labels = bs.classify_observations_by_duration(metadata)

fig, axes, axl = bs.plot_timeseries_by_group(data, metadata, sets_incubations, 'C_bc_rem_rel', titles=sets_labels,
                                             ylabel="Biochar C remaining (%)", factor=100,
                                             saveFig=False)
# Out:
# Incubation longer than 30 months --->  17  observations
# Incubation longer than 20 months --->  44  observations
# Incubation longer than 12 months --->  15  observations
# Incubation longer than 0 months --->  61  observations

# %% [markdown]
# ## Look at some of the metadata available

# %%
metadata['HHT'].hist() # quick histogram of pyrolysis temperatures
# Out:
# <AxesSubplot: >

# %%
# %matplotlib inline

metadata.replace('na', np.nan, inplace=True) 
    # missing data in the metadata is sometimes noted as "na", 
    # meaning it was not available in the work. These must be removed before plotting.
    
with sns.axes_style("darkgrid"):    
    # Correlation
    corr = metadata.corr(method='pearson', numeric_only=True)
    mask = np.triu(np.ones_like(corr, dtype=bool)).T
    meta_numeric = corr.columns

    f, ax = plt.subplots(figsize=(15, 15))
    cmap = sns.diverging_palette(230, 20, as_cmap=True)

    #corr[['BC_50', 'BC_100', 'BC_150', 'BC_200']]
    sns.heatmap(corr, cmap=cmap, center=0, mask=mask,
                square=True, linewidths=.9, linecolor='white',
                cbar_kws={"shrink": .5},
                annot=True, annot_kws={"size": 8}, fmt='.1f')

    ax.tick_params(axis='both', which='major', labelsize=10, 
                   labelbottom = False, bottom=False, top = True, labeltop=True, left=True,
                   pad=0)

    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='left', verticalalignment='baseline',
                       parse_math=True);

# %% [markdown]
# ## Curve fitting examples

# %%
# try out some curve-fitting - uscing scipy (library)
x, y = bs.select_timeseries(46, data, 'C_bc_rem_rel', factor=100)
p_opt, p_cov, p_std, r2, _, _, _ = bs.do_the_fit(f_model=bs.doubleExp, xdata=x, ydata=y,
                                              p0=None, method='trf', bounds=(-np.Inf,np.Inf), showPlot=True)
# Out:
# c:\github\biocharstability\biocharStability\analyse.py:65: RuntimeWarning: overflow encountered in exp
#   return c1*np.exp(-k1*t)+ (100-c1)*np.exp(-k2*t)
# [[Fit Statistics]]
#     # data points:  89
#     # variables:  3
#     chi-square:  77.70029487599595
#     reduced chi-square:  0.9034918008836739
#     Akaike info crit:  -6.084181240401
#     Bayesian info crit:  1.3817278687954193
# [[Variables]]
#     k1: 0.006865347151018146 +/- 0.0027403003416655767 (39.91495668590021 %)
#     k2: 0.00023046410544521828 +/- 1.3366235332871934e-05 (5.799703735664429 %)
#     c1: 3.339973894740916 +/- 0.9665365878878663 (28.938447375584687 %)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k2, c1) = -0.9790772350183764
#     C(k1, c1) = -0.9246972295962504
#     C(k1, k2) = 0.8735597621209342

# %%
# try out some curve-fitting - uscing lmfit (library)
_ = bs.do_the_lmfit(f_model=bs.doubleExp, xdata=x, ydata=y, method='trf', bounds=(0,1000), showPlot=True)
# Out:
# c:\github\biocharstability\biocharStability\analyse.py:65: RuntimeWarning: overflow encountered in exp
#   return c1*np.exp(-k1*t)+ (100-c1)*np.exp(-k2*t)
# [[Fit Statistics]]
#     # fitting method   = Nelder-Mead
#     # function evals   = 296
#     # data points      = 89
#     # variables        = 3
#     chi-square         = 77.7003632
#     reduced chi-square = 0.90349260
#     Akaike info crit   = -6.08410297
#     Bayesian info crit = 1.38180614
# [[Variables]]
#     k1:  0.00686153 +/- 0.00235439 (34.31%) (init = 0)
#     k2:  2.3043e-04 +/- 1.1954e-05 (5.19%) (init = 0)
#     c1:  3.34310584 +/- 0.84949648 (25.41%) (init = 0)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(k2, c1) = -0.974
#     C(k1, c1) = -0.901
#     C(k1, k2) = 0.838

# %% [markdown]
# Many more things can be done with functions pre-built in the library.
#
# Check out the documentation to explore the functions available.
#
# Check out the next demo notebook.
#
# Cheers.
